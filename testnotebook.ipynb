# %%
from nv import *
from numpy import random
import pytensor.tensor as pt
import pymc as pm
import arviz as az

# %%
#print(dipole_field_pt(1,1,1,1,1,1,1,1,1))

# %%
#path = get_file_path("example_data")
#print(path)
test = load_data("example_data")
print(test)
# Out:
# <xarray.Dataset> Size: 17kB
# Dimensions:  (index: 45)
# Coordinates:
#   * index    (index) int64 360B 0 1 2 3 4 5 6 7 8 ... 36 37 38 39 40 41 42 43 44
# Data variables: (12/45)
#     0        (index) float64 360B 153.5 157.2 161.7 164.5 ... 156.8 159.9 158.4
#     1        (index) float64 360B 160.2 154.7 163.4 158.3 ... 155.3 157.6 152.6
#     2        (index) float64 360B 157.5 158.7 164.8 159.6 ... 154.5 153.4 150.2
#     3        (index) float64 360B 154.7 158.5 156.5 160.4 ... 152.9 150.5 156.5
#     4        (index) float64 360B 152.9 152.9 156.5 159.1 ... 153.0 152.0 158.9
#     5        (index) float64 360B 154.7 155.6 162.9 164.9 ... 150.6 155.1 155.7
#     ...       ...
#     39       (index) float64 360B 146.0 143.1 149.1 143.2 ... 129.4 121.8 129.3
#     40       (index) float64 360B 140.2 145.7 151.4 143.8 ... 134.1 129.7 125.9
#     41       (index) float64 360B 148.5 153.7 148.4 138.1 ... 131.4 126.3 131.7
# ...
